# %%
from InstagramAPI import InstagramAPI
import time

# %%
username="prashantsinha718870@gmail.com"

# %%
psswrd = "ksingh718870"

# %%
InstagramAPI = InstagramAPI(username, psswrd)

# %%
InstagramAPI.login()
# Out:
# Request return 429 error!
# {'message': 'Please wait a few minutes before you try again.', 'status': 'fail'}
# Login success!
# True

# %%
InstagramAPI.logout()

# %%
InstagramAPI.isLoggedIn
InstagramAPI.LastJson
# Out:
# {'aymf': {'items': [{'user': {'pk': '223874422',
#      'username': 'thefunnyride',
#      'full_name': 'Aditya Dubey',
#      'is_private': False,
#      'profile_pic_url': 'https://scontent-sin6-2.cdninstagram.com/vp/841af860ee1eef0ddbf4e24ad69edef9/5BF8A019/t51.2885-19/s150x150/35575526_191084988252400_8324898117283479552_n.jpg',
#      'profile_pic_id': '1816707192856749861_223874422',
#      'is_verified': False,
#      'has_anonymous_profile_picture': False,
#      'reel_auto_archive': 'on'},
#     'algorithm': 'fuzzy_facebook_friends_algorithm',
#     'social_context': '',
#     'icon': '',
#     'caption': 'I’m an aspiring stand-up comic who spends his days procrastinating or making memes.\nFind my name on the Hall Of Lame!',
#     'media_ids': [],
#     'thumbnail_urls': [],
#     'large_urls': [],
#     'media_infos': [],
#     'value': 0.0019175,
#     'is_new_suggestion': False,
#     'uuid': '8329344001|1533031769'},
#    {'user': {'pk': '1644380505',
# ...

# %%
InstagramAPI.tagFeed("zoom")
# Out:
# True

# %%
result = InstagramAPI.LastJson

# %%
result
# Out:
# {'ranked_items': [{'taken_at': 1532682189,
#    'pk': 1832593250494489205,
#    'id': '1832593250494489205_7783848140',
#    'device_timestamp': 1532682160914738,
#    'media_type': 2,
#    'code': 'BlurdoRgKJ1',
#    'client_cache_key': 'MTgzMjU5MzI1MDQ5NDQ4OTIwNQ==.2',
#    'filter_type': 0,
#    'image_versions2': {'candidates': [{'width': 640,
#       'height': 800,
#       'url': 'https://scontent-sin6-2.cdninstagram.com/vp/adad89cde5a50d83305f8e6f651eea74/5B62D133/t51.2885-15/e15/37397026_200827660614008_4749601915132706816_n.jpg?ig_cache_key=MTgzMjU5MzI1MDQ5NDQ4OTIwNQ%3D%3D.2'},
#      {'width': 240,
#       'height': 300,
#       'url': 'https://scontent-sin6-2.cdninstagram.com/vp/8c87c3e1badf73bdc388b9eed6a1bda3/5B62768B/t51.2885-15/e15/p240x240/37397026_200827660614008_4749601915132706816_n.jpg?ig_cache_key=MTgzMjU5MzI1MDQ5NDQ4OTIwNQ%3D%3D.2'}]},
#    'original_width': 640,
#    'original_height': 800,
#    'video_versions': [{'type': 101,
#      'width': 640,
# ...

# %%
url = result["ranked_items"][0]["image_versions2"]["candidates"][0]['url']

# %%
import numpy as np
import urllib
import cv2
from skimage import io

# %%
image = io.imread(url)

# %%
#cv2.imshow("Incorrect", image)
cv2.imshow("Correct", cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
cv2.waitKey(0)
# Out:
# -1
